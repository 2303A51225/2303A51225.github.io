# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51225/2303A51225.github.io/blob/main/09_05_2026_TRAINING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 5
for i in range(1, n + 1):
    for j in range(i):
        print((i + j) % 2, end=" ")
    print()
# Out:
# 1
# 0 1
# 1 0 1
# 0 1 0 1
# 1 0 1 0 1
